# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''
# Out:
# '\nA Convolutional Network implementation example using TensorFlow library.\nThis example is using the MNIST database of handwritten digits\n(http://yann.lecun.com/exdb/mnist/)\n\nAuthor: Aymeric Damien\nProject: https://github.com/aymericdamien/TensorFlow-Examples/\n'

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
from __future__ import print_function
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 33877.601562, Training Accuracy= 0.23438
# Iter 2560, Minibatch Loss= 14085.191406, Training Accuracy= 0.48438
# Iter 3840, Minibatch Loss= 6633.567383, Training Accuracy= 0.61719
# Iter 5120, Minibatch Loss= 4079.210938, Training Accuracy= 0.73438
# Iter 6400, Minibatch Loss= 5302.139648, Training Accuracy= 0.76562
# Iter 7680, Minibatch Loss= 6009.117188, Training Accuracy= 0.82031
# Iter 8960, Minibatch Loss= 2637.731445, Training Accuracy= 0.85156
# Iter 10240, Minibatch Loss= 3230.434814, Training Accuracy= 0.89844
# Iter 11520, Minibatch Loss= 2952.464355, Training Accuracy= 0.85156
# Iter 12800, Minibatch Loss= 2327.349121, Training Accuracy= 0.86719
# Iter 14080, Minibatch Loss= 1277.543213, Training Accuracy= 0.92969
# Iter 15360, Minibatch Loss= 3982.132080, Training Accuracy= 0.80469
# Iter 16640, Minibatch Loss= 2242.836670, Training Accuracy= 0.89844
# Iter 17920, Minibatch Loss= 2131.965088, Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 2109.031250, Training Accuracy= 0.89062
# Iter 20480, Minibatch Loss= 1383.756592, Training Accuracy= 0.89062
# Iter 21760, Minibatch Loss= 1357.672119, Training Accuracy= 0.91406
# Iter 23040, Minibatch Loss= 1535.685791, Training Accuracy= 0.93750
# Iter 24320, Minibatch Loss= 2148.789307, Training Accuracy= 0.89062
# Iter 25600, Minibatch Loss= 2721.011719, Training Accuracy= 0.86719
# Iter 26880, Minibatch Loss= 653.295898, Training Accuracy= 0.93750
# Iter 28160, Minibatch Loss= 1422.507812, Training Accuracy= 0.91406
# Iter 29440, Minibatch Loss= 999.294800, Training Accuracy= 0.95312
# Iter 30720, Minibatch Loss= 1196.898682, Training Accuracy= 0.90625
# Iter 32000, Minibatch Loss= 896.386719, Training Accuracy= 0.92188
# Iter 33280, Minibatch Loss= 2305.453613, Training Accuracy= 0.95312
# Iter 34560, Minibatch Loss= 1638.178711, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 1586.629639, Training Accuracy= 0.91406
# Iter 37120, Minibatch Loss= 1195.192627, Training Accuracy= 0.90625
# Iter 38400, Minibatch Loss= 782.201782, Training Accuracy= 0.92969
# Iter 39680, Minibatch Loss= 1144.246826, Training Accuracy= 0.92969
# Iter 40960, Minibatch Loss= 223.767334, Training Accuracy= 0.98438
# Iter 42240, Minibatch Loss= 1156.782471, Training Accuracy= 0.94531
# Iter 43520, Minibatch Loss= 952.060547, Training Accuracy= 0.93750
# Iter 44800, Minibatch Loss= 244.870178, Training Accuracy= 0.96094
# Iter 46080, Minibatch Loss= 922.276611, Training Accuracy= 0.92969
# Iter 47360, Minibatch Loss= 799.541260, Training Accuracy= 0.94531
# Iter 48640, Minibatch Loss= 912.670959, Training Accuracy= 0.92188
# Iter 49920, Minibatch Loss= 610.690002, Training Accuracy= 0.93750
# Iter 51200, Minibatch Loss= 1306.360107, Training Accuracy= 0.89062
# Iter 52480, Minibatch Loss= 808.280884, Training Accuracy= 0.93750
# Iter 53760, Minibatch Loss= 927.273071, Training Accuracy= 0.93750
# Iter 55040, Minibatch Loss= 981.530396, Training Accuracy= 0.94531
# Iter 56320, Minibatch Loss= 723.744019, Training Accuracy= 0.96094
# Iter 57600, Minibatch Loss= 769.457275, Training Accuracy= 0.94531
# Iter 58880, Minibatch Loss= 586.650513, Training Accuracy= 0.96875
# Iter 60160, Minibatch Loss= 1000.828247, Training Accuracy= 0.93750
# Iter 61440, Minibatch Loss= 602.837341, Training Accuracy= 0.95312
# Iter 62720, Minibatch Loss= 326.910553, Training Accuracy= 0.96094
# Iter 64000, Minibatch Loss= 1340.732178, Training Accuracy= 0.93750
# Iter 65280, Minibatch Loss= 883.859802, Training Accuracy= 0.91406
# Iter 66560, Minibatch Loss= 595.555786, Training Accuracy= 0.96094
# Iter 67840, Minibatch Loss= 401.742371, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 939.963257, Training Accuracy= 0.91406
# Iter 70400, Minibatch Loss= 133.049133, Training Accuracy= 0.98438
# Iter 71680, Minibatch Loss= 358.244080, Training Accuracy= 0.95312
# Iter 72960, Minibatch Loss= 429.201233, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 577.535217, Training Accuracy= 0.92969
# Iter 75520, Minibatch Loss= 308.228516, Training Accuracy= 0.96875
# Iter 76800, Minibatch Loss= 767.676514, Training Accuracy= 0.93750
# Iter 78080, Minibatch Loss= 576.470581, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 361.248535, Training Accuracy= 0.96094
# Iter 80640, Minibatch Loss= 369.274811, Training Accuracy= 0.95312
# Iter 81920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 83200, Minibatch Loss= 555.549561, Training Accuracy= 0.95312
# Iter 84480, Minibatch Loss= 735.532104, Training Accuracy= 0.95312
# Iter 85760, Minibatch Loss= 561.167480, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 6.909576, Training Accuracy= 0.99219
# Iter 88320, Minibatch Loss= 228.103607, Training Accuracy= 0.98438
# Iter 89600, Minibatch Loss= 445.956848, Training Accuracy= 0.96094
# Iter 90880, Minibatch Loss= 869.092712, Training Accuracy= 0.92188
# Iter 92160, Minibatch Loss= 451.830078, Training Accuracy= 0.97656
# Iter 93440, Minibatch Loss= 191.232651, Training Accuracy= 0.98438
# Iter 94720, Minibatch Loss= 31.085114, Training Accuracy= 0.99219
# Iter 96000, Minibatch Loss= 510.745697, Training Accuracy= 0.95312
# Iter 97280, Minibatch Loss= 812.819702, Training Accuracy= 0.94531
# Iter 98560, Minibatch Loss= 422.626251, Training Accuracy= 0.95312
# Iter 99840, Minibatch Loss= 237.584885, Training Accuracy= 0.96875
# Iter 101120, Minibatch Loss= 536.447449, Training Accuracy= 0.92969
# Iter 102400, Minibatch Loss= 233.301804, Training Accuracy= 0.95312
# Iter 103680, Minibatch Loss= 587.969238, Training Accuracy= 0.94531
# Iter 104960, Minibatch Loss= 283.490356, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 400.024994, Training Accuracy= 0.96875
# Iter 107520, Minibatch Loss= 428.952972, Training Accuracy= 0.96094
# Iter 108800, Minibatch Loss= 1198.830933, Training Accuracy= 0.94531
# Iter 110080, Minibatch Loss= 593.477661, Training Accuracy= 0.93750
# Iter 111360, Minibatch Loss= 93.038162, Training Accuracy= 0.98438
# Iter 112640, Minibatch Loss= 96.237961, Training Accuracy= 0.98438
# Iter 113920, Minibatch Loss= 480.458710, Training Accuracy= 0.94531
# Iter 115200, Minibatch Loss= 319.558441, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 191.285263, Training Accuracy= 0.96094
# Iter 117760, Minibatch Loss= 363.083252, Training Accuracy= 0.93750
# Iter 119040, Minibatch Loss= 269.637573, Training Accuracy= 0.96875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-f47b6d8897a6> in <module>()
#      14             loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
#      15                                                               y: batch_y,
# ---> 16                                                               keep_prob: 1.})
#      17             print("Iter " + str(step*batch_size) + ", Minibatch Loss= " +                   "{:.6f}".format(loss) + ", Training Accuracy= " +                   "{:.5f}".format(acc))
#      18         step += 1
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
