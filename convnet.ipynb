# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''
# Out:
# '\nA Convolutional Network implementation example using TensorFlow library.\nThis example is using the MNIST database of handwritten digits\n(http://yann.lecun.com/exdb/mnist/)\n\nAuthor: Aymeric Damien\nProject: https://github.com/aymericdamien/TensorFlow-Examples/\n'

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
from __future__ import print_function
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 26065.734375, Training Accuracy= 0.24219
# Iter 2560, Minibatch Loss= 9794.315430, Training Accuracy= 0.55469
# Iter 3840, Minibatch Loss= 7773.297852, Training Accuracy= 0.60156
# Iter 5120, Minibatch Loss= 5192.260742, Training Accuracy= 0.78906
# Iter 6400, Minibatch Loss= 3327.409424, Training Accuracy= 0.85156
# Iter 7680, Minibatch Loss= 2469.174072, Training Accuracy= 0.85938
# Iter 8960, Minibatch Loss= 2104.395508, Training Accuracy= 0.89844
# Iter 10240, Minibatch Loss= 1693.606445, Training Accuracy= 0.88281
# Iter 11520, Minibatch Loss= 1653.301025, Training Accuracy= 0.90625
# Iter 12800, Minibatch Loss= 3456.959229, Training Accuracy= 0.90625
# Iter 14080, Minibatch Loss= 2318.235596, Training Accuracy= 0.85938
# Iter 15360, Minibatch Loss= 1645.175537, Training Accuracy= 0.89062
# Iter 16640, Minibatch Loss= 845.660400, Training Accuracy= 0.92969
# Iter 17920, Minibatch Loss= 1452.080444, Training Accuracy= 0.87500
# Iter 19200, Minibatch Loss= 1525.100586, Training Accuracy= 0.87500
# Iter 20480, Minibatch Loss= 2518.635498, Training Accuracy= 0.89844
# Iter 21760, Minibatch Loss= 1815.434937, Training Accuracy= 0.88281
# Iter 23040, Minibatch Loss= 1236.675293, Training Accuracy= 0.91406
# Iter 24320, Minibatch Loss= 2058.599854, Training Accuracy= 0.89844
# Iter 25600, Minibatch Loss= 1164.373535, Training Accuracy= 0.92188
# Iter 26880, Minibatch Loss= 1131.161865, Training Accuracy= 0.96094
# Iter 28160, Minibatch Loss= 841.729187, Training Accuracy= 0.92188
# Iter 29440, Minibatch Loss= 896.288940, Training Accuracy= 0.92188
# Iter 30720, Minibatch Loss= 1093.136353, Training Accuracy= 0.92969
# Iter 32000, Minibatch Loss= 609.660278, Training Accuracy= 0.92969
# Iter 33280, Minibatch Loss= 1502.712280, Training Accuracy= 0.93750
# Iter 34560, Minibatch Loss= 1479.082520, Training Accuracy= 0.92188
# Iter 35840, Minibatch Loss= 1418.904541, Training Accuracy= 0.90625
# Iter 37120, Minibatch Loss= 1157.440308, Training Accuracy= 0.93750
# Iter 38400, Minibatch Loss= 672.813416, Training Accuracy= 0.95312
# Iter 39680, Minibatch Loss= 1426.410767, Training Accuracy= 0.93750
# Iter 40960, Minibatch Loss= 1974.077393, Training Accuracy= 0.89062
# Iter 42240, Minibatch Loss= 484.813904, Training Accuracy= 0.94531
# Iter 43520, Minibatch Loss= 598.348389, Training Accuracy= 0.95312
# Iter 44800, Minibatch Loss= 1274.003662, Training Accuracy= 0.92188
# Iter 46080, Minibatch Loss= 1070.623779, Training Accuracy= 0.93750
# Iter 47360, Minibatch Loss= 374.585754, Training Accuracy= 0.93750
# Iter 48640, Minibatch Loss= 273.605530, Training Accuracy= 0.96875
# Iter 49920, Minibatch Loss= 240.191376, Training Accuracy= 0.97656
# Iter 51200, Minibatch Loss= 1070.160767, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 256.690399, Training Accuracy= 0.96875
# Iter 53760, Minibatch Loss= 351.351166, Training Accuracy= 0.96094
# Iter 55040, Minibatch Loss= 1125.364258, Training Accuracy= 0.92969
# Iter 56320, Minibatch Loss= 513.026917, Training Accuracy= 0.94531
# Iter 57600, Minibatch Loss= 376.633911, Training Accuracy= 0.97656
# Iter 58880, Minibatch Loss= 880.971619, Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 236.269775, Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 549.276794, Training Accuracy= 0.96094
# Iter 62720, Minibatch Loss= 240.202530, Training Accuracy= 0.97656
# Iter 64000, Minibatch Loss= 537.497192, Training Accuracy= 0.96875
# Iter 65280, Minibatch Loss= 975.640320, Training Accuracy= 0.95312
# Iter 66560, Minibatch Loss= 191.763611, Training Accuracy= 0.96094
# Iter 67840, Minibatch Loss= 230.595749, Training Accuracy= 0.97656
# Iter 69120, Minibatch Loss= 466.091614, Training Accuracy= 0.95312
# Iter 70400, Minibatch Loss= 59.598328, Training Accuracy= 0.98438
# Iter 71680, Minibatch Loss= 145.041107, Training Accuracy= 0.96875
# Iter 72960, Minibatch Loss= 361.589172, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 287.754150, Training Accuracy= 0.96094
# Iter 75520, Minibatch Loss= 834.766968, Training Accuracy= 0.95312
# Iter 76800, Minibatch Loss= 401.204163, Training Accuracy= 0.95312
# Iter 78080, Minibatch Loss= 489.173950, Training Accuracy= 0.95312
# Iter 79360, Minibatch Loss= 432.938660, Training Accuracy= 0.95312
# Iter 80640, Minibatch Loss= 830.877808, Training Accuracy= 0.94531
# Iter 81920, Minibatch Loss= 646.549072, Training Accuracy= 0.96094
# Iter 83200, Minibatch Loss= 788.485962, Training Accuracy= 0.92969
# Iter 84480, Minibatch Loss= 360.389771, Training Accuracy= 0.94531
# Iter 85760, Minibatch Loss= 328.678772, Training Accuracy= 0.95312
# Iter 87040, Minibatch Loss= 302.622986, Training Accuracy= 0.95312
# Iter 88320, Minibatch Loss= 157.017822, Training Accuracy= 0.97656
# Iter 89600, Minibatch Loss= 212.879837, Training Accuracy= 0.98438
# Iter 90880, Minibatch Loss= 494.622040, Training Accuracy= 0.95312
# Iter 92160, Minibatch Loss= 201.657654, Training Accuracy= 0.97656
# Iter 93440, Minibatch Loss= 539.850220, Training Accuracy= 0.94531
# Iter 94720, Minibatch Loss= 379.475922, Training Accuracy= 0.97656
# Iter 96000, Minibatch Loss= 305.517303, Training Accuracy= 0.96875
# Iter 97280, Minibatch Loss= 345.853485, Training Accuracy= 0.96094
# Iter 98560, Minibatch Loss= 318.486450, Training Accuracy= 0.96875
# Iter 99840, Minibatch Loss= 918.937378, Training Accuracy= 0.92969
# Iter 101120, Minibatch Loss= 418.766907, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 694.451233, Training Accuracy= 0.94531
# Iter 103680, Minibatch Loss= 583.931885, Training Accuracy= 0.90625
# Iter 104960, Minibatch Loss= 636.769165, Training Accuracy= 0.93750
# Iter 106240, Minibatch Loss= 383.375946, Training Accuracy= 0.96094
# Iter 107520, Minibatch Loss= 345.449188, Training Accuracy= 0.96875
# Iter 108800, Minibatch Loss= 308.060913, Training Accuracy= 0.96875
# Iter 110080, Minibatch Loss= 435.409515, Training Accuracy= 0.93750
# Iter 111360, Minibatch Loss= 328.005951, Training Accuracy= 0.95312
# Iter 112640, Minibatch Loss= 417.623108, Training Accuracy= 0.95312
# Iter 113920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 115200, Minibatch Loss= 513.919312, Training Accuracy= 0.95312
# Iter 116480, Minibatch Loss= 518.050171, Training Accuracy= 0.92188
# Iter 117760, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 119040, Minibatch Loss= 257.836243, Training Accuracy= 0.97656
# Iter 120320, Minibatch Loss= 131.800629, Training Accuracy= 0.99219
# Iter 121600, Minibatch Loss= 307.438965, Training Accuracy= 0.97656
# Iter 122880, Minibatch Loss= 604.256897, Training Accuracy= 0.92969
# Iter 124160, Minibatch Loss= 244.110443, Training Accuracy= 0.96094
# Iter 125440, Minibatch Loss= 67.091400, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 33.610214, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 36.516335, Training Accuracy= 0.98438
# Iter 129280, Minibatch Loss= 88.431427, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 185.647430, Training Accuracy= 0.95312
# Iter 131840, Minibatch Loss= 113.604332, Training Accuracy= 0.98438
# Iter 133120, Minibatch Loss= 151.680511, Training Accuracy= 0.97656
# Iter 134400, Minibatch Loss= 450.131653, Training Accuracy= 0.94531
# Iter 135680, Minibatch Loss= 444.407043, Training Accuracy= 0.96094
# Iter 136960, Minibatch Loss= 36.044556, Training Accuracy= 0.98438
# Iter 138240, Minibatch Loss= 39.250458, Training Accuracy= 0.97656
# Iter 139520, Minibatch Loss= 134.648743, Training Accuracy= 0.96875
# Iter 140800, Minibatch Loss= 208.008347, Training Accuracy= 0.96875
# Iter 142080, Minibatch Loss= 455.260040, Training Accuracy= 0.95312
# Iter 143360, Minibatch Loss= 254.351364, Training Accuracy= 0.98438
# Iter 144640, Minibatch Loss= 276.958466, Training Accuracy= 0.96094
# Iter 145920, Minibatch Loss= 107.371384, Training Accuracy= 0.97656
# Iter 147200, Minibatch Loss= 46.125290, Training Accuracy= 0.98438
# Iter 148480, Minibatch Loss= 44.495781, Training Accuracy= 0.98438
# Iter 149760, Minibatch Loss= 83.315483, Training Accuracy= 0.98438
# Iter 151040, Minibatch Loss= 153.673859, Training Accuracy= 0.96875
# Iter 152320, Minibatch Loss= 154.434875, Training Accuracy= 0.96094
# Iter 153600, Minibatch Loss= 169.564758, Training Accuracy= 0.97656
# Iter 154880, Minibatch Loss= 145.095795, Training Accuracy= 0.98438
# Iter 156160, Minibatch Loss= 71.967972, Training Accuracy= 0.98438
# Iter 157440, Minibatch Loss= 214.396149, Training Accuracy= 0.96094
# Iter 158720, Minibatch Loss= 486.305664, Training Accuracy= 0.93750
# Iter 160000, Minibatch Loss= 64.836487, Training Accuracy= 0.97656
# Iter 161280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 162560, Minibatch Loss= 222.598114, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 50.799286, Training Accuracy= 0.98438
# Iter 165120, Minibatch Loss= 131.865067, Training Accuracy= 0.98438
# Iter 166400, Minibatch Loss= 187.136414, Training Accuracy= 0.96875
# Iter 167680, Minibatch Loss= 547.385742, Training Accuracy= 0.92188
# Iter 168960, Minibatch Loss= 1.640793, Training Accuracy= 0.99219
# Iter 170240, Minibatch Loss= 105.189049, Training Accuracy= 0.97656
# Iter 171520, Minibatch Loss= 16.577164, Training Accuracy= 0.97656
# Iter 172800, Minibatch Loss= 202.164368, Training Accuracy= 0.96875
# Iter 174080, Minibatch Loss= 203.991608, Training Accuracy= 0.97656
# Iter 175360, Minibatch Loss= 563.490723, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 452.004395, Training Accuracy= 0.96094
# Iter 177920, Minibatch Loss= 68.514862, Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 207.228851, Training Accuracy= 0.94531
# Iter 180480, Minibatch Loss= 162.066650, Training Accuracy= 0.98438
# Iter 181760, Minibatch Loss= 59.342175, Training Accuracy= 0.98438
# Iter 183040, Minibatch Loss= 20.845459, Training Accuracy= 0.98438
# Iter 184320, Minibatch Loss= 68.546921, Training Accuracy= 0.97656
# Iter 185600, Minibatch Loss= 155.977478, Training Accuracy= 0.97656
# Iter 186880, Minibatch Loss= 32.543259, Training Accuracy= 0.97656
# Iter 188160, Minibatch Loss= 77.381966, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 161.243576, Training Accuracy= 0.95312
# Iter 190720, Minibatch Loss= 254.760483, Training Accuracy= 0.96875
# Iter 192000, Minibatch Loss= 88.071960, Training Accuracy= 0.97656
# Iter 193280, Minibatch Loss= 120.045273, Training Accuracy= 0.95312
# Iter 194560, Minibatch Loss= 49.207405, Training Accuracy= 0.98438
# Iter 195840, Minibatch Loss= 73.578354, Training Accuracy= 0.98438
# Iter 197120, Minibatch Loss= 113.229309, Training Accuracy= 0.97656
# Iter 198400, Minibatch Loss= 101.964386, Training Accuracy= 0.96094
# Iter 199680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 1.0
